# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train_cleaned.csv")

# %%
df.select_dtypes(include=[np.number])
# Out:
#       MSSubClass  LotFrontage  LotArea  Street  Alley  LotShape  LandSlope  \
# 0             10         65.0     8450       1      1         3          0
# 1              5         80.0     9600       1      1         3          0
# 2             10         68.0    11250       1      1         0          0
# 3             11         60.0     9550       1      1         0          0
# 4             10         84.0    14260       1      1         0          0
# 5              9         85.0    14115       1      1         0          0
# 6              5         75.0    10084       1      1         3          0
# 7             10         80.0    10382       1      1         0          0
# 8              9         51.0     6120       1      1         3          0
# 9              4         50.0     7420       1      1         3          0
# 10             5         70.0    11200       1      1         3          0
# ...

# %% [markdown]
# df.columns
