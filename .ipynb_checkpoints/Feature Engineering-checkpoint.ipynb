# %% [markdown]
# # Predicting House Prices
#
# [Kaggle Competition Link](https://www.kaggle.com/c/house-prices-advanced-regression-techniques)
#
# Inspired by [Serigne](https://www.kaggle.com/serigne/stacked-regressions-top-4-on-leaderboard?fbclid=IwAR2njt-MxaSsIJ0zED_VdPdgs_ZdgA_Th8meaOBtjWuS8qMJtzDJ754eo94) and [Laurenstc](https://www.kaggle.com/laurenstc/top-2-of-leaderboard-advanced-fe/notebook?fbclid=IwAR0PHkeKShKgqEJjxXw4_X7FptfMW1Iz59Gi74O-fYqJG_-naQh04oceRZ8)'s kaggle notebooks. A big part of the feature engineering is based on their code.
#
# * feature engineering
# * prediction methods
# * results
# * Improvements

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# %matplotlib inline

# %%
test = pd.read_csv("test.csv")
print(len(test))
train = pd.read_csv("train.csv")
print(len(train))
# Out:
# 1459
# 1460

# %%
plt.scatter(train["GrLivArea"], train["SalePrice"])
plt.show()

# %%
#removing outliers with GrLivArea > 4500 
train = train[train["GrLivArea"]<4500]

# %%
len(train["Id"].value_counts()) #unqiue 1458
len(train) #1458

len(test["Id"].value_counts()) #1459
len(test) #1459

#drop id since they are just like the index column 
train = train.drop("Id", axis =1)
test = test.drop("Id", axis = 1)

# %%
orginal_index = train["SalePrice"].reset_index(drop = True) 
#drop parameter in reset index aovids the old index being added as a column

# %%
df1 = train.drop("SalePrice", axis = 1)
df2 = test

# %%
df = pd.concat([df1,df2]).reset_index(drop = True)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0    NaN
# 1         Lvl    AllPub       FR2      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Corner      ...                 0        0    NaN
# 4         Lvl    AllPub       FR2      ...                 0        0    NaN
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0   NaN         NaN       0       2    2008        WD         Normal
# 1   NaN         NaN       0       5    2007        WD         Normal
# 2   NaN         NaN       0       9    2008        WD         Normal
# 3   NaN         NaN       0       2    2006        WD        Abnorml
# 4   NaN         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %% [markdown]
# ## Data Transformation
# * need not transform response variable at least for the moment
# * The log or transformation of response y is based on seing heterescedasticrtity in residual plots.
# * the histograms of response variables need not be close to normal. The assumption of MLR is that errors are normall distributed with a common variance.
# * this need not emply that the histogram of respones(y) is normall distributed.
# * if there are many similar vectors of x's then the distribution of y;s over this subset with simlar x vectors is close to normal

# %%
plt.hist(train["SalePrice"])
#right skewed so reponse is not as normal,
#therefore we would observe response distribution later after observing variance
# Out:
# (array([ 148.,  722.,  372.,  135.,   51.,   19.,    4.,    3.,    2.,    2.]),
#  array([  34900.,  106910.,  178920.,  250930.,  322940.,  394950.,
#          466960.,  538970.,  610980.,  682990.,  755000.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Observing Na's

# %%
# construct missing ratio 
df_na = df.isnull().sum()*100/len(df)
df_na = df_na.drop(df_na[df_na ==0].index).sort_values(ascending =False)
#len(df_na) # =34
df_na # this is seen as the missing data ratio in the predictor variables
# Out:
# PoolQC          99.691464
# MiscFeature     96.400411
# Alley           93.212204
# Fence           80.425094
# FireplaceQu     48.680151
# LotFrontage     16.660953
# GarageFinish     5.450806
# GarageYrBlt      5.450806
# GarageQual       5.450806
# GarageCond       5.450806
# GarageType       5.382242
# BsmtExposure     2.811107
# BsmtCond         2.811107
# BsmtQual         2.776826
# BsmtFinType2     2.742544
# BsmtFinType1     2.708262
# MasVnrType       0.822763
# MasVnrArea       0.788481
# MSZoning         0.137127
# BsmtFullBath     0.068564
# BsmtHalfBath     0.068564
# Utilities        0.068564
# Functional       0.068564
# Exterior2nd      0.034282
# Exterior1st      0.034282
# SaleType         0.034282
# BsmtFinSF1       0.034282
# BsmtFinSF2       0.034282
# BsmtUnfSF        0.034282
# Electrical       0.034282
# KitchenQual      0.034282
# GarageCars       0.034282
# GarageArea       0.034282
# TotalBsmtSF      0.034282
# dtype: float64

# %%
df["PoolQC"].sort_values()
# We see that there are Ex Fa and Gd
# we can fill all NaN's to None becoming the 4th category
df["PoolQC"] = df["PoolQC"].fillna("None")

# %%
#Nan meaning no misc feature 
df["MiscFeature"].sort_values()
#fill with None as 4th category
df["MiscFeature"] = df["MiscFeature"].fillna("None")
#do that for the similar predictor variables
df["Alley"] = df["Alley"].fillna("None")
df["Fence"] = df["Fence"].fillna("None")
df["FireplaceQu"] = df["FireplaceQu"].fillna("None")

# %%
# fill the missing values with the median of the data
# since we can assume the linear feet of street connected to the property is similar
# lot frontage: means that portion of a lot that abuts a public or private street. 
df["LotFrontage"] = df.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
df.groupby("Neighborhood")["LotFrontage"].median()
# Out:
# Neighborhood
# Blmngtn    43.0
# Blueste    24.0
# BrDale     21.0
# BrkSide    51.0
# ClearCr    80.5
# CollgCr    70.0
# Crawfor    70.0
# Edwards    64.5
# Gilbert    64.0
# IDOTRR     60.0
# MeadowV    21.0
# Mitchel    74.0
# NAmes      73.0
# NPkVill    24.0
# NWAmes     80.0
# NoRidge    89.0
# NridgHt    92.0
# OldTown    60.0
# SWISU      60.0
# Sawyer     72.0
# SawyerW    67.0
# Somerst    72.5
# StoneBr    60.0
# Timber     82.0
# Veenker    80.0
# Name: LotFrontage, dtype: float64

# %%
df["GarageType"] = df["GarageType"].fillna("None")
df["GarageFinish"] = df["GarageFinish"].fillna("None")
df["GarageQual"] = df["GarageQual"].fillna("None")
df["GarageCond"] = df["GarageCond"].fillna("None")

#fill with 0 since no garage => no cars
df["GarageYrBlt"] = df["GarageYrBlt"].fillna(0)
df["GarageArea"] = df["GarageArea"].fillna(0)
df["GarageCars"] = df["GarageCars"].fillna(0)

# %%
#there are quite a few more nulls we need to fix
nulls = np.sum(df.isnull())
len(nulls[nulls != 0]) # 21 more we need to fix 
nulls[nulls != 0]
# Out:
# MSZoning         4
# Utilities        2
# Exterior1st      1
# Exterior2nd      1
# MasVnrType      24
# MasVnrArea      23
# BsmtQual        81
# BsmtCond        82
# BsmtExposure    82
# BsmtFinType1    79
# BsmtFinSF1       1
# BsmtFinType2    80
# BsmtFinSF2       1
# BsmtUnfSF        1
# TotalBsmtSF      1
# Electrical       1
# BsmtFullBath     2
# BsmtHalfBath     2
# KitchenQual      1
# Functional       2
# SaleType         1
# dtype: int64

# %%
#Only 4 missing 
np.sum(df["MSZoning"].isnull())
df["MSZoning"].value_counts()
#lets just fill the na's with RL since it is the most common 
df["MSZoning"] = df["MSZoning"].fillna("RL")

# %%
#Most common value is TA since only 1 observation is missing lets use it to fill the NaN
df["KitchenQual"].value_counts()
df["KitchenQual"] =df["KitchenQual"].fillna("SBrkr")

# %%
#This does not help since the data is unbalance, may mess up training and holdout 
df["Utilities"].value_counts()
df = df.drop(['Utilities'], axis=1)

# %%
#Since only missing 1 observation fill with most common value
df['Exterior1st'] = df['Exterior1st'].fillna(df['Exterior1st'].mode()[0])
df['Exterior2nd'] = df['Exterior2nd'].fillna(df['Exterior2nd'].mode()[0])

# %%
df["MasVnrType"].value_counts()
# Out:
# None       1742
# BrkFace     879
# Stone       247
# BrkCmn       25
# Name: MasVnrType, dtype: int64

# %%
#Na meaning no masonry veneer fill None and 0 
df["MasVnrType"] = df["MasVnrType"].fillna("None")
df["MasVnrArea"] = df["MasVnrArea"].fillna(0)

# %% [markdown]
# # Basement related variables

# %%
#In this case the missing values suggest that there is not basement 
nulls = np.sum(df.isnull())
nulls[nulls != 0]
# Out:
# BsmtQual        81
# BsmtCond        82
# BsmtExposure    82
# BsmtFinType1    79
# BsmtFinSF1       1
# BsmtFinType2    80
# BsmtFinSF2       1
# BsmtUnfSF        1
# TotalBsmtSF      1
# Electrical       1
# BsmtFullBath     2
# BsmtHalfBath     2
# Functional       2
# SaleType         1
# dtype: int64

# %%
#we fill with 0
for i in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    df[i] = df[i].fillna(0)

# %%
#Observe the basement related columns
df[['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1','BsmtFinType2', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF']].head()
# Out:
#   BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  BsmtFinSF1  \
# 0       Gd       TA           No          GLQ          Unf       706.0
# 1       Gd       TA           Gd          ALQ          Unf       978.0
# 2       Gd       TA           Mn          GLQ          Unf       486.0
# 3       TA       Gd           No          ALQ          Unf       216.0
# 4       Gd       TA           Av          GLQ          Unf       655.0
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 0         0.0      150.0        856.0
# 1         0.0      284.0       1262.0
# 2         0.0      434.0        920.0
# 3         0.0      540.0        756.0
# 4         0.0      490.0       1145.0

# %%
#NaN in this case would mean no basement so we replace with none
for i in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    df[i] = df[i].fillna('None')

# %% [markdown]
# # Electrical, Functional and SaleType varialbe

# %%
nulls = np.sum(df.isnull())
nulls[nulls != 0]
#each of these aren't missing much data
# Out:
# Electrical    1
# Functional    2
# SaleType      1
# dtype: int64

# %%
#since the electrical variable is only missing one observation we will replace with the most common observation,
#which is "SBrkr"
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])

#As in the data description NA means Typical, which is Typ
df["Functional"] = df['Functional'].fillna("Typ")

#Fill in with the most frequent SaleType since only missing one observation
df['SaleType'] = df['SaleType'].fillna(df['SaleType'].mode()[0])

# %%
nulls = np.sum(df.isnull())
nulls[nulls != 0]
#We have filled in all the NA's
# Out:
# Series([], dtype: int64)

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# # Change Numerical variables to Categorical

# %%
df['MSSubClass'] = df['MSSubClass'].apply(str)
df['OverallCond'] = df['OverallCond'].astype(str)
df['YrSold'] = df['YrSold'].astype(str)
df['MoSold'] = df['MoSold'].astype(str)

# %%
# Create new variable as total are of the house, which is just summing up the basement, 1st, and 2nd floor.
df['TotalSF'] = df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF']

# %%
from sklearn.preprocessing import LabelEncoder
variables = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')

for v in variables:
    labels = LabelEncoder() 
    labels.fit(list(df[v].values)) 
    df[v] = labels.transform(list(df[v].values))

# shape        
print('Shape all_data: {}'.format(df.shape))


#Encode labels for future prediction use of categorical variables
# Out:
# Shape all_data: (2917, 79)

# %% [markdown]
# # Incorrect Data

# %%
pd.set_option('display.max_columns', None)
df.describe()
#Lets observe all the values to see if there is something weird
# Out:
#         MSSubClass  LotFrontage        LotArea       Street        Alley  \
# count  2917.000000  2917.000000    2917.000000  2917.000000  2917.000000
# mean      7.132328    69.436064   10139.439150     0.995886     0.985602
# std       3.699114    21.208242    7807.036512     0.064018     0.260180
# min       0.000000    21.000000    1300.000000     0.000000     0.000000
# 25%       5.000000    60.000000    7476.000000     1.000000     1.000000
# 50%       5.000000    70.000000    9452.000000     1.000000     1.000000
# 75%      10.000000    80.000000   11556.000000     1.000000     1.000000
# max      15.000000   313.000000  215245.000000     1.000000     2.000000
#
#           LotShape    LandSlope  OverallQual  OverallCond    YearBuilt  \
# count  2917.000000  2917.000000  2917.000000  2917.000000  2917.000000
# mean      1.948234     0.053822     6.086390     4.564964  1971.287967
# std       1.409743     0.248831     1.406704     1.113414    30.286991
# min       0.000000     0.000000     1.000000     0.000000  1872.000000
# 25%       0.000000     0.000000     5.000000     4.000000  1953.000000
# 50%       3.000000     0.000000     6.000000     4.000000  1973.000000
# 75%       3.000000     0.000000     7.000000     5.000000  2001.000000
# max       3.000000     2.000000    10.000000     8.000000  2010.000000
#
#        YearRemodAdd   MasVnrArea    ExterQual    ExterCond     BsmtQual  \
# count   2917.000000  2917.000000  2917.000000  2917.000000  2917.000000
# mean    1984.248200   100.931436     2.532396     3.708605     2.701748
# std       20.892257   178.032499     0.699350     0.773869     1.294777
# min     1950.000000     0.000000     0.000000     0.000000     0.000000
# 25%     1965.000000     0.000000     2.000000     4.000000     2.000000
# 50%     1993.000000     0.000000     3.000000     4.000000     2.000000
# 75%     2004.000000   163.000000     3.000000     4.000000     4.000000
# max     2010.000000  1600.000000     3.000000     4.000000     4.000000
#
#           BsmtCond  BsmtExposure  BsmtFinType1   BsmtFinSF1  BsmtFinType2  \
# count  2917.000000   2917.000000   2917.000000  2917.000000   2917.000000
# mean      3.673980      2.328420      3.183750   438.864930      5.549537
# std       0.977272      1.151038      2.235724   444.180542      1.273893
# min       0.000000      0.000000      0.000000     0.000000      0.000000
# 25%       4.000000      2.000000      2.000000     0.000000      6.000000
# 50%       4.000000      3.000000      2.000000   368.000000      6.000000
# 75%       4.000000      3.000000      6.000000   733.000000      6.000000
# max       4.000000      4.000000      6.000000  4010.000000      6.000000
#
#         BsmtFinSF2   BsmtUnfSF  TotalBsmtSF    HeatingQC   CentralAir  \
# count  2917.000000  2917.00000  2917.000000  2917.000000  2917.000000
# mean     49.599246   560.50360  1048.967775     1.534796     0.932808
# std     169.232130   439.69883   429.472008     1.742682     0.250398
# min       0.000000     0.00000     0.000000     0.000000     0.000000
# 25%       0.000000   220.00000   793.000000     0.000000     1.000000
# 50%       0.000000   467.00000   988.000000     0.000000     1.000000
# 75%       0.000000   804.00000  1302.000000     4.000000     1.000000
# max    1526.000000  2336.00000  5095.000000     4.000000     1.000000
#
#           1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  BsmtFullBath  \
# count  2917.000000  2917.000000   2917.000000  2917.000000   2917.000000
# mean   1157.692492   335.861502      4.697635  1498.251628      0.428865
# std     385.264298   428.119663     46.412570   496.908626      0.523943
# min     334.000000     0.000000      0.000000   334.000000      0.000000
# 25%     876.000000     0.000000      0.000000  1126.000000      0.000000
# 50%    1082.000000     0.000000      0.000000  1444.000000      0.000000
# 75%    1384.000000   704.000000      0.000000  1743.000000      1.000000
# max    5095.000000  2065.000000   1064.000000  5095.000000      3.000000
#
#        BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  KitchenAbvGr  \
# count   2917.000000  2917.000000  2917.000000   2917.000000   2917.000000
# mean       0.061364     1.567364     0.379842      2.860130      1.044566
# std        0.245687     0.552465     0.502782      0.822967      0.214532
# min        0.000000     0.000000     0.000000      0.000000      0.000000
# 25%        0.000000     1.000000     0.000000      2.000000      1.000000
# 50%        0.000000     2.000000     0.000000      3.000000      1.000000
# 75%        0.000000     2.000000     1.000000      3.000000      1.000000
# max        2.000000     4.000000     2.000000      8.000000      3.000000
#
#        KitchenQual  TotRmsAbvGrd   Functional   Fireplaces  FireplaceQu  \
# count  2917.000000   2917.000000  2917.000000  2917.000000  2917.000000
# mean      2.860130      6.448063     5.759685     0.596160     3.072335
# std       1.268611      1.564281     0.935605     0.644773     1.145118
# min       0.000000      2.000000     0.000000     0.000000     0.000000
# 25%       2.000000      5.000000     6.000000     0.000000     2.000000
# 50%       4.000000      6.000000     6.000000     1.000000     3.000000
# 75%       4.000000      7.000000     6.000000     1.000000     3.000000
# max       4.000000     15.000000     6.000000     4.000000     5.000000
#
#        GarageYrBlt  GarageFinish   GarageCars   GarageArea   GarageQual  \
# count  2917.000000   2917.000000  2917.000000  2917.000000  2917.000000
# mean   1870.270141      1.875557     1.765513   472.247515     4.689407
# std     449.826161      1.201826     0.762102   214.762268     0.950526
# min       0.000000      0.000000     0.000000     0.000000     0.000000
# 25%    1957.000000      1.000000     1.000000   320.000000     5.000000
# 50%    1977.000000      2.000000     2.000000   480.000000     5.000000
# 75%    2001.000000      3.000000     2.000000   576.000000     5.000000
# max    2207.000000      3.000000     5.000000  1488.000000     5.000000
#
#         GarageCond   PavedDrive   WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# count  2917.000000  2917.000000  2917.000000  2917.000000    2917.000000
# mean      4.764141     1.830648    93.629414    47.280082      23.114158
# std       0.803313     0.537465   126.532643    67.118965      64.263424
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       5.000000     2.000000     0.000000     0.000000       0.000000
# 50%       5.000000     2.000000     0.000000    26.000000       0.000000
# 75%       5.000000     2.000000   168.000000    70.000000       0.000000
# max       5.000000     2.000000  1424.000000   742.000000    1012.000000
#
#          3SsnPorch  ScreenPorch     PoolArea       PoolQC        Fence  \
# count  2917.000000  2917.000000  2917.000000  2917.000000  2917.000000
# mean      2.604045    16.073363     2.088790     2.993486     3.493315
# std      25.196714    56.202054    34.561371     0.126789     1.091669
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     3.000000     4.000000
# 50%       0.000000     0.000000     0.000000     3.000000     4.000000
# 75%       0.000000     0.000000     0.000000     3.000000     4.000000
# max     508.000000   576.000000   800.000000     3.000000     4.000000
#
#             MiscVal       MoSold       YrSold       TotalSF
# count   2917.000000  2917.000000  2917.000000   2917.000000
# mean      50.860816     6.512856     1.792938   2542.521769
# std      567.595198     2.983653     1.315328    781.071852
# min        0.000000     0.000000     0.000000    334.000000
# 25%        0.000000     5.000000     1.000000   2000.000000
# 50%        0.000000     7.000000     2.000000   2448.000000
# 75%        0.000000     9.000000     3.000000   2990.000000
# max    17000.000000    11.000000     4.000000  10190.000000

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0          10       RL         65.0     8450       1      1         3
# 1           5       RL         80.0     9600       1      1         3
# 2          10       RL         68.0    11250       1      1         0
# 3          11       RL         60.0     9550       1      1         0
# 4          10       RL         84.0    14260       1      1         0
#
#   LandContour LotConfig  LandSlope Neighborhood Condition1 Condition2  \
# 0         Lvl    Inside          0      CollgCr       Norm       Norm
# 1         Lvl       FR2          0      Veenker      Feedr       Norm
# 2         Lvl    Inside          0      CollgCr       Norm       Norm
# 3         Lvl    Corner          0      Crawfor       Norm       Norm
# 4         Lvl       FR2          0      NoRidge       Norm       Norm
#
#   BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0     1Fam     2Story            7            4       2003          2003
# 1     1Fam     1Story            6            7       1976          1976
# 2     1Fam     2Story            7            4       2001          2002
# 3     1Fam     2Story            7            4       1915          1970
# 4     1Fam     2Story            8            4       2000          2000
#
#   RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea  \
# 0     Gable  CompShg     VinylSd     VinylSd    BrkFace       196.0
# 1     Gable  CompShg     MetalSd     MetalSd       None         0.0
# 2     Gable  CompShg     VinylSd     VinylSd    BrkFace       162.0
# 3     Gable  CompShg     Wd Sdng     Wd Shng       None         0.0
# 4     Gable  CompShg     VinylSd     VinylSd    BrkFace       350.0
#
#    ExterQual  ExterCond Foundation  BsmtQual  BsmtCond  BsmtExposure  \
# 0          2          4      PConc         2         4             3
# 1          3          4     CBlock         2         4             1
# 2          2          4      PConc         2         4             2
# 3          3          4     BrkTil         4         1             3
# 4          2          4      PConc         2         4             0
#
#    BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0             2       706.0             6         0.0      150.0        856.0
# 1             0       978.0             6         0.0      284.0       1262.0
# 2             2       486.0             6         0.0      434.0        920.0
# 3             0       216.0             6         0.0      540.0        756.0
# 4             2       655.0             6         0.0      490.0       1145.0
#
#   Heating  HeatingQC  CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA          0           1      SBrkr       856       854             0
# 1    GasA          0           1      SBrkr      1262         0             0
# 2    GasA          0           1      SBrkr       920       866             0
# 3    GasA          2           1      SBrkr       961       756             0
# 4    GasA          0           1      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710           1.0           0.0         2         1             3
# 1       1262           0.0           1.0         2         0             3
# 2       1786           1.0           0.0         2         1             3
# 3       1717           1.0           0.0         1         0             3
# 4       2198           1.0           0.0         2         1             4
#
#    KitchenAbvGr  KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  \
# 0             1            2             8           6           0
# 1             1            4             6           6           1
# 2             1            2             6           6           1
# 3             1            2             7           6           1
# 4             1            2             9           6           1
#
#    FireplaceQu GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea  \
# 0            3     Attchd       2003.0             2         2.0       548.0
# 1            5     Attchd       1976.0             2         2.0       460.0
# 2            5     Attchd       2001.0             2         2.0       608.0
# 3            2     Detchd       1998.0             3         3.0       642.0
# 4            5     Attchd       2000.0             2         3.0       836.0
#
#    GarageQual  GarageCond  PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 0           5           5           2           0           61              0
# 1           5           5           2         298            0              0
# 2           5           5           2           0           42              0
# 3           5           5           2           0           35            272
# 4           5           5           2         192           84              0
#
#    3SsnPorch  ScreenPorch  PoolArea  PoolQC  Fence MiscFeature  MiscVal  \
# 0          0            0         0       3      4        None        0
# 1          0            0         0       3      4        None        0
# 2          0            0         0       3      4        None        0
# 3          0            0         0       3      4        None        0
# 4          0            0         0       3      4        None        0
#
#    MoSold  YrSold SaleType SaleCondition  TotalSF
# 0       4       2       WD        Normal   2566.0
# 1       7       1       WD        Normal   2524.0
# 2      11       2       WD        Normal   2706.0
# 3       4       0       WD       Abnorml   2473.0
# 4       3       2       WD        Normal   3343.0

# %% [markdown]
# # Change YearBuilt, YearRemodAdd and GarageYrBlt
# * I think it makes more sense to change these into ages

# %%
import datetime
df["Age"] = datetime.datetime.now().year-df['YearBuilt'] 
df["RemodAge"] = datetime.datetime.now().year-df['YearRemodAdd']
df["GarageAge"] = datetime.datetime.now().year-df['GarageYrBlt']

# %% [markdown]
# ## GarageYrBlt
# * The max is not correct it goes up to 2207
# * this is most likely 2007 (an input error)

# %%
df[df["GarageYrBlt"] == 2207]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 2590           5       RL         68.0     8298       1      1         0
#
#      LandContour LotConfig  LandSlope Neighborhood Condition1 Condition2  \
# 2590         HLS    Inside          0       Timber       Norm       Norm
#
#      BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 2590     1Fam     1Story            8            4       2006          2007
#
#      RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea  \
# 2590       Hip  CompShg     VinylSd     VinylSd       None         0.0
#
#       ExterQual  ExterCond Foundation  BsmtQual  BsmtCond  BsmtExposure  \
# 2590          2          4      PConc         2         4             0
#
#       BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  BsmtUnfSF  \
# 2590             2       583.0             6         0.0      963.0
#
#       TotalBsmtSF Heating  HeatingQC  CentralAir Electrical  1stFlrSF  \
# 2590       1546.0    GasA          0           1      SBrkr      1564
#
#       2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  \
# 2590         0             0       1564           0.0           0.0         2
#
#       HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  TotRmsAbvGrd  \
# 2590         0             2             1            0             6
#
#       Functional  Fireplaces  FireplaceQu GarageType  GarageYrBlt  \
# 2590           6           1            2     Attchd       2207.0
#
#       GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  \
# 2590             2         2.0       502.0           5           5
#
#       PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 2590           2         132            0              0          0
#
#       ScreenPorch  PoolArea  PoolQC  Fence MiscFeature  MiscVal  MoSold  \
# 2590            0         0       3      4        None        0      11
#
#       YrSold SaleType SaleCondition  TotalSF  Age  RemodAge  GarageAge
# 2590       1      New       Partial   3110.0   13        12     -188.0

# %%
#change by locating the wrong row
df.loc[2590, 'GarageYrBlt'] = 2007

# %% [markdown]
# # Changing Data Types

# %%
type(df["MSSubClass"][1])
#this should be a factor instead of an integer
# Out:
# numpy.int64

# %%
type(df["MoSold"][1])
# Out:
# numpy.int64

# %%
#factors = ['MSSubClass', 'MoSold']
df.update(df["MoSold"].astype('str'))
df.update(df['MSSubClass'].astype('str'))

# %% [markdown]
# # Fixing skewness with data transform

# %%
from scipy.stats import skew

numerical_columns = list(df.select_dtypes(include=[np.number]).head().columns)

# %%
skewness = df[numerical_columns].apply(lambda x: skew(x)).sort_values(ascending=False)
skews = pd.DataFrame({'skew':skewness})
skews
# Out:
#                     skew
# MiscVal        21.939672
# PoolArea       17.688664
# LotArea        13.109495
# LowQualFinSF   12.084539
# 3SsnPorch      11.372080
# LandSlope       4.973254
# KitchenAbvGr    4.300550
# BsmtFinSF2      4.144503
# EnclosedPorch   4.002344
# ScreenPorch     3.945101
# BsmtHalfBath    3.929996
# GarageAge       3.904632
# MasVnrArea      2.621719
# OpenPorchSF     2.529358
# WoodDeckSF      1.844792
# 1stFlrSF        1.257286
# LotFrontage     1.103039
# GrLivArea       1.068750
# TotalSF         1.009157
# BsmtFinSF1      0.980645
# BsmtUnfSF       0.919688
# 2ndFlrSF        0.861556
# TotRmsAbvGrd    0.749232
# Fireplaces      0.725278
# HalfBath        0.696666
# TotalBsmtSF     0.671751
# BsmtFullBath    0.622415
# Age             0.599194
# OverallCond     0.569314
# HeatingQC       0.485534
# RemodAge        0.450134
# FireplaceQu     0.332611
# BedroomAbvGr    0.326568
# GarageArea      0.216857
# OverallQual     0.189591
# FullBath        0.165514
# YrSold          0.131996
# BsmtFinType1    0.083641
# GarageCars     -0.219297
# YearRemodAdd   -0.450134
# BsmtQual       -0.488362
# YearBuilt      -0.599194
# GarageFinish   -0.609953
# LotShape       -0.618564
# KitchenQual    -0.625423
# Alley          -0.651705
# BsmtExposure   -1.117321
# ExterQual      -1.800062
# Fence          -1.992649
# ExterCond      -2.496489
# BsmtCond       -2.861271
# PavedDrive     -2.977741
# BsmtFinType2   -3.042979
# GarageQual     -3.072788
# CentralAir     -3.457555
# GarageCond     -3.594290
# GarageYrBlt    -3.905250
# Functional     -4.054126
# Street        -15.494756
# PoolQC        -21.217600

# %%
from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax

high_skew = skews[abs(skews) > 0.5]

# %%
skew_index = high_skew.index
for i in skew_index:
    df[i]= boxcox1p(df[i], 0.15)
#boxcox_normmax(df[i]+1)

# %%
        
skewness2 = df[numerical_columns].apply(lambda x: skew(x)).sort_values(ascending=False)
skews2 = pd.DataFrame({'skew':skewness2})
skews2
# Out:
#                     skew
# PoolArea       15.759529
# 3SsnPorch       8.921650
# LowQualFinSF    8.741030
# MiscVal         5.594963
# LandSlope       4.530264
# BsmtHalfBath    3.786685
# KitchenAbvGr    3.697303
# ScreenPorch     2.977052
# BsmtFinSF2      2.563235
# EnclosedPorch   2.024321
# MasVnrArea      0.637388
# HalfBath        0.592548
# BsmtFullBath    0.441787
# 2ndFlrSF        0.328879
# HeatingQC       0.286444
# Fireplaces      0.285310
# WoodDeckSF      0.224181
# 1stFlrSF        0.179117
# LotArea         0.177735
# TotRmsAbvGrd    0.135489
# GrLivArea       0.130051
# RemodAge        0.100289
# OpenPorchSF     0.099381
# Age            -0.120935
# FullBath       -0.180093
# TotalSF        -0.208003
# YrSold         -0.400635
# YearRemodAdd   -0.456199
# BsmtFinSF1     -0.488866
# OverallQual    -0.488928
# BsmtFinType1   -0.490310
# YearBuilt      -0.621621
# LotShape       -0.646266
# BedroomAbvGr   -0.753468
# LotFrontage    -0.798905
# FireplaceQu    -0.806142
# GarageFinish   -0.855645
# OverallCond    -0.929427
# GarageCars     -1.106367
# BsmtQual       -1.267091
# KitchenQual    -1.400982
# BsmtExposure   -1.408080
# BsmtUnfSF      -1.537286
# Fence          -2.537398
# Alley          -2.626957
# ExterQual      -2.853936
# ExterCond      -3.013484
# GarageArea     -3.044799
# PavedDrive     -3.064108
# BsmtCond       -3.228260
# GarageQual     -3.440572
# CentralAir     -3.457555
# BsmtFinType2   -3.770065
# GarageYrBlt    -3.923774
# TotalBsmtSF    -3.985466
# GarageCond     -4.174418
# Functional     -5.124718
# Street        -15.494756
# PoolQC        -22.823847
# GarageAge            NaN

# %% [markdown]
# # Dummy Categorical Variables

# %%
df = pd.get_dummies(df).reset_index(drop=True)
df.shape
# Out:
# (2917, 249)

# %% [markdown]
# # Back to Train and Test set

# %%
X = df.iloc[:len(train["SalePrice"]),:]
X.shape
# Out:
# (1458, 249)

# %%
test_df= df.iloc[len(X):,:]
test_df.shape
# Out:
# (1459, 249)

# %%
np.all(np.isfinite(train["SalePrice"]))
# Out:
# True

# %%
np.any(np.isnan(train["SalePrice"]))
# Out:
# False

# %%
np.all(np.isfinite(X))
# Out:
# True

# %%
np.any(np.isnan(X)) # This is because of dummies
# Out:
# False

# %% [markdown]
# Seems like our X and y both seems fine so we can proceed

# %% [markdown]
# # Add the price column back on the train set

# %%
X["SalePrice"] = train["SalePrice"]
# Out:
# /Users/chi/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X.to_csv("X.csv", index = False)
y = train["SalePrice"]
y.to_csv("y.csv", index = False)

# %%
test_df.to_csv("test_cleaned.csv", index = False)
